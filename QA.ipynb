# %%
from backend import DVH

filepath1 = r'ejemplos_dvh\12616855_VMI_DVH_1.txt'
filepath2 = r'ejemplos_dvh\68216079_PrmVsVMAT_DVH_1.txt'

dvh1 = DVH(filepath1)
dvh2 = DVH(filepath2)

for key, structure in dvh1.structures.items():
    print(f"{key}")
    print(f"    Dmed= {structure.mean:.1f} cGy")
print("/n")

for key, structure in dvh2.structures.items():
    print(f"{key}")
    print(f"    Dmed= {structure.mean:.1f} cGy")
# Out:
# CORAZON
#     Dmed= 188.3 cGy
# ESOFAGO
#     Dmed= 43.5 cGy
# MAMA_D
#     Dmed= 33.0 cGy
# MEDULA
#     Dmed= 22.3 cGy
# PACIENTE
#     Dmed= 198.4 cGy
# PTV_VMI
#     Dmed= 2636.0 cGy
# PULMON_D
#     Dmed= 30.5 cGy
# PULMON_I
#     Dmed= 363.2 cGy
# VENTRICULO_I
#     Dmed= 324.2 cGy
# /n
# BULBO_PENEANO
#     Dmed= 646.7 cGy
# CAUDA_EQUINA
#     Dmed= 29.3 cGy
# CTV_PR
#     Dmed= 6212.0 cGy
# CTV_VS
#     Dmed= 6223.6 cGy
# FEMUR_D
#     Dmed= 968.1 cGy
# FEMUR_I
#     Dmed= 1072.6 cGy
# GENITALES
#     Dmed= 170.6 cGy
# INTESTINO
#     Dmed= 21.9 cGy
# PACIENTE
#     Dmed= 294.3 cGy
# PRV_CAUDA_EQUINA
#     Dmed= 31.8 cGy
# PTV_PR
#     Dmed= 6168.0 cGy
# PTV_VS
#     Dmed= 6169.2 cGy
# RECTO
#     Dmed= 2601.3 cGy
# SIGMA
#     Dmed= 121.5 cGy
# VEJIGA
#     Dmed= 925.6 cGy
